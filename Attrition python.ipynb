# %%
import pandas as pd

# %%
Attrition=pd.read_csv( r'C:\Users\anush\Desktop\Attrition.csv')

# %%
Attrition.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
summary_stats = Attrition.describe(include='all')
summary_stats
# Out:
#          EmployeeID          Age Attrition BusinessTravel  \
# count   4410.000000  4410.000000      4410           4410
# unique          NaN          NaN         2              3
# top             NaN          NaN        No  Travel_Rarely
# freq            NaN          NaN      3699           3129
# mean    2205.500000    36.923810       NaN            NaN
# std     1273.201673     9.133301       NaN            NaN
# min        1.000000    18.000000       NaN            NaN
# 25%     1103.250000    30.000000       NaN            NaN
# 50%     2205.500000    36.000000       NaN            NaN
# 75%     3307.750000    43.000000       NaN            NaN
# max     4410.000000    60.000000       NaN            NaN
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     4410       4410.000000  4410.000000           4410
# unique                       3               NaN          NaN              6
# ...

# %%
Attrition_encoded = pd.get_dummies(Attrition, drop_first=True)

# %%
Attrition.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
correlation_matrix = Attrition_encoded.corr()

# %%
Attrition.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
attrition_correlation = correlation_matrix["Attrition_Yes"].sort_values(ascending=False)

# %%
print(attrition_correlation)
# Out:
# Attrition_Yes                        1.000000
# MaritalStatus_Single                 0.175419
# BusinessTravel_Travel_Frequently     0.115143
# JobRole_Research Director            0.049760
# NumCompaniesWorked                   0.042345
# PercentSalaryHike                    0.032533
# JobRole_Research Scientist           0.027460
# PerformanceRating                    0.023403
# Gender_Male                          0.018125
# EducationField_Life Sciences         0.012394
# JobRole_Sales Executive              0.010869
# JobRole_Laboratory Technician        0.001179
# EducationField_Medical               0.000764
# EducationField_Marketing            -0.003780
# EmployeeID                          -0.004729
# StockOptionLevel                    -0.006839
# DistanceFromHome                    -0.009730
# JobLevel                            -0.010290
# JobRole_Sales Representative        -0.011073
# JobRole_Human Resources             -0.013857
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
#Age Distribution of Employeesplt.figure(figsize=(10, 6))
sns.histplot(Attrition['Age'], kde=True, bins=30)
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Attrition by Department
plt.figure(figsize=(10, 6))
sns.countplot(data=Attrition, x='Department', hue='Attrition',palette='pastel')
plt.title('Attrition by Department')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.legend(title='Attrition')
plt.show()

# %%
#Attrition by Education
plt.figure(figsize=(10, 6))
sns.countplot(data=Attrition, x='Education', hue='Attrition')
plt.title('Attrition by Education')
plt.xlabel('Education Level')
plt.ylabel('Number of Employees')
plt.legend(title='Attrition')
plt.show()

# %%
#Attrition by Marital Status
plt.figure(figsize=(10, 6))
sns.countplot(data=Attrition, x='MaritalStatus', hue='Attrition')
plt.title('Attrition by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Number of Employees')
plt.legend(title='Attrition')
plt.show()

# %%
#Histogram of numeric variables
num_bins = 10

Attrition.hist(bins=num_bins, figsize=(20,15))
plt.savefig("Attrition_histogram_plots")
plt.show()
